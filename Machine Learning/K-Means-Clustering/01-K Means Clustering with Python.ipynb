# %% [markdown]
# # K Means Clustering with Python
#
# This notebook is just a code reference for the video lecture and reading.
#
# ## Method Used
#
# K Means Clustering is an unsupervised learning algorithm that tries to cluster data based on their similarity. Unsupervised learning means that there is no outcome to be predicted, and the algorithm just tries to find patterns in the data. In k means clustering, we have the specify the number of clusters we want the data to be grouped into. The algorithm randomly assigns each observation to a cluster, and finds the centroid of each cluster. Then, the algorithm iterates through two steps:
# Reassign data points to the cluster whose centroid is closest. Calculate new centroid of each cluster. These two steps are repeated till the within cluster variation cannot be reduced any further. The within cluster variation is calculated as the sum of the euclidean distance between the data points and their respective cluster centroids.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Create some Data

# %%
from sklearn.datasets import make_blobs

# %%
# Create Data
data = make_blobs(n_samples=200, n_features=2, 
                           centers=4, cluster_std=1.8,random_state=101)
data
# Out:
# (array([[-6.42884095e+00,  1.01411174e+01],
#         [ 5.86867888e+00,  5.20110356e+00],
#         [-3.76109375e-01,  3.26427943e+00],
#         [ 2.16679181e+00,  9.56300522e+00],
#         [ 5.09508570e+00,  7.20752718e+00],
#         [-1.08788882e+01, -6.11318040e+00],
#         [ 2.03405554e+00,  9.76664755e+00],
#         [-1.71798771e+00,  1.41401140e+00],
#         [ 1.16911341e+00,  8.24556988e+00],
#         [-1.35185444e+00,  3.13245345e+00],
#         [-6.18548214e+00,  9.67406555e+00],
#         [-1.19856602e+00,  2.50408937e+00],
#         [ 2.90296863e+00,  7.91251003e+00],
#         [ 2.39250023e+00,  5.38173971e+00],
#         [-5.27545147e+00,  9.63836659e+00],
#         [-5.66814687e-01,  5.60262755e-02],
#         [ 5.97336628e+00,  5.87172022e+00],
#         [-2.31355268e+00,  5.23980092e-01],
#         [-1.01344756e+01, -3.43130837e+00],
#         [-4.54082629e+00,  1.13920174e+01],
#         [-1.04155833e+01, -5.67545836e+00],
# ...

# %%
np.sum(data[1] == 2)
# Out:
# 50

# %% [markdown]
# ## Visualize Data

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(6,6))
sns.scatterplot(data[0][:,0],data[0][:,1],hue=data[1],palette='rainbow')

# %% [markdown]
# ## Creating the Clusters

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=4, verbose=1)
kmeans2 = KMeans(n_clusters=5, verbose=2)

# %%
kmeans.fit(data[0])
kmeans2.fit(data[0])
# Out:
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1468.9308061473066
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1348.436864124054
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1323.9668646413422
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1318.4262922181688
# start iteration
# done sorting
# end inner loop
# Iteration 4, inertia 1318.4262922181688
# center shift 0.000000e+00 within tolerance 3.158498e-03
# Initialization complete
# start iteration
# done sorting
# end inner loop
# Iteration 0, inertia 1964.9095091748009
# start iteration
# done sorting
# end inner loop
# Iteration 1, inertia 1436.1171826833954
# start iteration
# done sorting
# end inner loop
# Iteration 2, inertia 1347.1192264537385
# start iteration
# done sorting
# end inner loop
# Iteration 3, inertia 1330.0544186545703
# start iteration
# done sorting
# end inner loop
# ...

# %%
kmeans.cluster_centers_
# Out:
# array([[ 3.71749226,  7.01388735],
#        [-9.46941837, -6.56081545],
#        [-4.13591321,  7.95389851],
#        [-0.0123077 ,  2.13407664]])

# %%
kmeans.labels_
# Out:
# array([2, 0, 3, 0, 0, 1, 0, 3, 0, 3, 2, 3, 0, 0, 2, 3, 0, 3, 1, 2, 1, 3,
#        3, 1, 2, 1, 1, 3, 0, 0, 2, 1, 0, 3, 3, 2, 1, 1, 1, 3, 1, 2, 2, 2,
#        3, 0, 2, 3, 1, 3, 3, 2, 0, 3, 1, 2, 3, 3, 2, 0, 1, 0, 1, 2, 0, 3,
#        1, 0, 0, 1, 0, 3, 1, 3, 1, 0, 0, 3, 2, 3, 3, 1, 0, 1, 3, 3, 3, 2,
#        3, 1, 1, 1, 1, 3, 3, 1, 0, 2, 1, 0, 3, 1, 3, 3, 0, 3, 1, 0, 1, 1,
#        0, 2, 2, 0, 1, 0, 2, 2, 0, 2, 3, 2, 3, 2, 3, 0, 2, 3, 1, 2, 2, 2,
#        3, 1, 1, 2, 0, 2, 0, 3, 1, 0, 1, 2, 2, 0, 3, 1, 2, 2, 2, 2, 3, 0,
#        3, 2, 0, 0, 0, 3, 0, 3, 3, 2, 1, 2, 3, 0, 2, 3, 0, 3, 2, 0, 3, 2,
#        0, 0, 1, 0, 2, 1, 1, 2, 1, 1, 1, 1, 1, 3, 1, 0, 0, 2, 1, 3, 0, 0,
#        1, 3])

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True,figsize=(12,6))
ax1.set_title('K Means Plot 1')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow',edgecolor='grey')
ax2.set_title("K Means Plot 2")
ax2.scatter(data[0][:,0],data[0][:,1],c=kmeans2.labels_,cmap='rainbow',edgecolor='grey')

# %%
data[1]
# Out:
# array([3, 2, 0, 2, 2, 1, 2, 0, 2, 0, 3, 0, 2, 2, 3, 0, 2, 0, 1, 3, 1, 0,
#        0, 1, 3, 1, 1, 0, 2, 2, 3, 1, 2, 0, 0, 3, 1, 1, 1, 2, 1, 3, 3, 3,
#        0, 3, 3, 0, 1, 2, 0, 3, 2, 0, 1, 3, 0, 0, 3, 2, 1, 2, 1, 3, 2, 0,
#        1, 2, 2, 1, 2, 0, 1, 3, 1, 2, 2, 0, 3, 0, 0, 1, 2, 1, 0, 0, 0, 3,
#        2, 1, 1, 1, 1, 3, 0, 1, 2, 3, 1, 2, 0, 1, 0, 0, 2, 0, 1, 2, 1, 1,
#        0, 3, 3, 2, 1, 2, 3, 3, 2, 3, 0, 3, 0, 3, 0, 2, 3, 0, 1, 3, 3, 3,
#        0, 1, 1, 3, 2, 3, 2, 0, 1, 2, 1, 3, 3, 2, 0, 1, 3, 3, 3, 3, 0, 2,
#        0, 3, 2, 2, 2, 0, 2, 0, 0, 3, 1, 3, 0, 2, 3, 0, 2, 0, 3, 3, 0, 3,
#        2, 2, 1, 2, 3, 1, 1, 3, 1, 1, 1, 1, 1, 0, 1, 2, 2, 3, 1, 0, 2, 2,
#        1, 0])

# %%
sns.countplot(kmeans.labels_ != data[1])

# %% [markdown]
# You should note, the colors are meaningless in reference between the two plots.

# %% [markdown]
# # Great Job!
